# %%
x = int(input("Enter Number :"))
y = int(input("Enter Number :"))
print(x+y)
# Out:
# Enter Number : 10
# Enter Number : 20
# 30

# %%
x,y  = [int(i) for i in input("Enter Number at :").split()]
print(x+y)
# Out:
# Enter Number at : 10 12
# 22

# %%
x= 10j
y =5
print(x/y)
# Out:
# 2j

# %%
int("12")+ 12
# Out:
# 24

# %%
 a ="""HEllo
 i am using multile lines"""
print(a)
# Out:
# HEllo
# i am using multile lines
