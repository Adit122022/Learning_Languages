# %%
# COntrol Flow Statement (also called as Conditonals statements)
num = int(input("Enter your number :"))
if num % 2 ==0:
    print("Number is Even")
else :
    printf("Number is Odd")
# Out:
# Enter your number : 50
# Number is Even

# %%
age = int(input("Enter your age :"))
if age >= 18:
    print("You are eligible to vote 😭😭!")
else :
    print("You are not eligible to vote 🥲🥲!")
# Out:
# Enter your age : 15
# You are not eligible to vote 🥲🥲!

# %%
num = int(input("Enter your number :"))
if num == 10:
    print("Number is equal to 10 🥰👍!")
elif num ==50:
    print("Number is equal to 50 🥰👍!!")
elif num ==100:
    print("Number is equal to 100 🥰👍!!")
else :
    print("Number is not equal to any number .Take back your number 😼😼",num)
# Out:
# Enter your number : 5
# Number is not equal to any number .Take back your number 😼😼 5
