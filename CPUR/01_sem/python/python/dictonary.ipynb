# %%
dict = {
    1 :"Geeks",
    2 :"For",
    "abc" :"Geeks", 
}
print(dict["abc"])
# Out:
# Geeks

# %%
d = {1: 'Geeks', 2: 'For',3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'}}

print(d[3]["A"],d[3]["B"],d[3]["C"])
# Out:
# Welcome To Geeks

# %%
print(d.get(1))
# Out:
# Geeks

# %%
info={
    "name":"aditya",
    "city":"kota",
    "age":"bacha",
    "email":"bacha12.com"
}
# a =info.keys()
# print(info)
# print(info.keys())
for k in info.keys():
    print(k ,info[k])
# Out:
# name aditya
# city kota
# age bacha
# email bacha12.com

# %%
print(dir(info))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
for k in info.items():
    print(k)
# Out:
# ('name', 'aditya')
# ('city', 'kota')
# ('age', 'bacha')
# ('email', 'bacha12.com')

# %%
key_list=['name','city','mob_no','age']

new_dict = info.fromkeys(key_list,"unknown")
      
# printing result
print ("New dictionary with empty lists as keys : " + str(new_dict))
# Out:
# New dictionary with empty lists as keys : {'name': 'unknown', 'city': 'unknown', 'mob_no': 'unknown', 'age': 'unknown'}

# %%
print(help(info.formkeys()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(help(info.formkeys()))
#
# AttributeError: 'dict' object has no attribute 'formkeys'
