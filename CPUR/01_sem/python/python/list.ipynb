# %%
l=[122,22223,324,5924,75,861,19965]
l.sort()
print(l)
# Out:
# [75, 122, 324, 861, 5924, 19965, 22223]

# %%
l=[122,22223,324,5924,75,861,19965]
l.sort()
print(l)
# Out:
# [22223, 19965, 5924, 861, 324, 122, 75]

# %%
l=["pallo","porld","python"]
l.sort()
print(l)
# Out:
# ['pallo', 'porld', 'python']

# %%
l=["a","y","u","e","n"]
l.sort()
print(l)
# Out:
# ['a', 'e', 'n', 'u', 'y']
